# %%
from lgui.editor import Editor
from lgui.components import Component

editor = Editor()
editor.sheet.add_component(
    Component(Component.R, 10)
)

editor.display()
